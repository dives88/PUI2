# %%
from __future__ import print_function
import pandas as pd
import os
import numpy as np
import urllib2
import sys
import json

# %%
#Imports -
from __future__ import print_function
import pandas as pd
import os
import numpy as np
import urllib2
import sys
import json

#Sys Arg - dictates what can be entered, and whether all infomation is present. Also stores MTA Key.
if len(sys.argv) != 3:
    print ("You did not enter the appropriate number of arguments. Please try again")
    sys.exit()

mta_key = "f029495e-f04b-4c63-ac5d-388cbe8bfb29"
bus_line = "B52"

url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=" + mta_key + "&VehicleMonitoringDetailLevel=calls&LineRef=" + bus_line


#Reading the Data - this sections helps read/process data into a format that can be manipulated.
response = urllib2.urlopen(url)
data_rough = response.read()
data = json.loads(data_rough)


#Getting info for each independent bus
indbus = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']


#Print bus line
print("Bus Line: "+ bus_line)


#Number of active busses
num_bus = str(len(indbus))
print("Number of Active Busses: " + num_bus)


#Loop to get the location of each independent bus
busno = 0
for i in indbus:
    longitude = str(i['MonitoredVehicleJourney']['VehicleLocation']['Longitude'])
    latitude = str(i['MonitoredVehicleJourney']['VehicleLocation']['Latitude'])
    print("Bus " + str(busno) + " is at latitude " + latitude + " and longitude " + longitude)
    busno += 1
# Out:
# Bus Line: B52
# Number of Active Busses: 13
# Bus 0 is at latitude 40.690478 and longitude -73.984898
# Bus 1 is at latitude 40.689614 and longitude -73.982744
# Bus 2 is at latitude 40.687245 and longitude -73.976751
# Bus 3 is at latitude 40.700101 and longitude -73.91164
# Bus 4 is at latitude 40.690777 and longitude -73.985647
# Bus 5 is at latitude 40.689447 and longitude -73.922442
# Bus 6 is at latitude 40.690252 and longitude -73.984338
# Bus 7 is at latitude 40.687376 and longitude -73.960048
# Bus 8 is at latitude 40.687651 and longitude -73.957666
# Bus 9 is at latitude 40.686077 and longitude -73.971329
# Bus 10 is at latitude 40.690261 and longitude -73.921308
# Bus 11 is at latitude 40.690366 and longitude -73.921204
# Bus 12 is at latitude 40.690408 and longitude -73.921162

# %%
indbus = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]
data
# Out:
# {u'Siri': {u'ServiceDelivery': {u'ResponseTimestamp': u'2017-09-23T16:15:00.391-04:00',
#    u'SituationExchangeDelivery': [],
#    u'VehicleMonitoringDelivery': [{u'ResponseTimestamp': u'2017-09-23T16:15:00.391-04:00',
#      u'ValidUntil': u'2017-09-23T16:16:00.391-04:00',
#      u'VehicleActivity': [{u'MonitoredVehicleJourney': {u'Bearing': 45.813477,
#         u'BlockRef': u'MTA NYCT_FP_D7-Saturday_A_FP_50640_B52-123',
#         u'DestinationName': u'RIDGEWOOD TERM via GATES',
#         u'DestinationRef': u'MTA_801117',
#         u'DirectionRef': u'0',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-23',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Saturday-091400_B52_123'},
#         u'JourneyPatternRef': u'MTA_B520040',
#         u'LineRef': u'MTA NYCT_B52',
#         u'Monitored': True,
#         u'MonitoredCall': {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#            u'DistanceFromCall': 0.0,
#            u'PresentableDistance': u'at stop',
#            u'StopsFromCall': 0}},
#          u'StopPointName': u'PALMETTO ST/IRVING AV',
#          u'StopPointRef': u'MTA_304415',
#          u'VisitNumber': 1},
#         u'OnwardCalls': {u'OnwardCall': [{u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#              u'DistanceFromCall': 0.0,
#              u'PresentableDistance': u'at stop',
#              u'StopsFromCall': 0}},
#            u'StopPointName': u'PALMETTO ST/IRVING AV',
#            u'StopPointRef': u'MTA_304415'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:15:05.999-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#              u'DistanceFromCall': 149.91,
#              u'PresentableDistance': u'approaching',
#              u'StopsFromCall': 1}},
#            u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#            u'StopPointRef': u'MTA_801117'}]},
#         u'OperatorRef': u'MTA NYCT',
#         u'OriginRef': u'MTA_307175',
#         u'ProgressRate': u'normalProgress',
#         u'PublishedLineName': u'B52',
#         u'SituationRef': [],
#         u'VehicleLocation': {u'Latitude': 40.69823, u'Longitude': -73.912314},
#         u'VehicleRef': u'MTA NYCT_3969'},
#        u'RecordedAtTime': u'2017-09-23T16:14:31.000-04:00'},
#       {u'MonitoredVehicleJourney': {u'Bearing': 6.401065,
#         u'BlockRef': u'MTA NYCT_FP_D7-Saturday_A_FP_51180_B52-116',
#         u'DestinationName': u'RIDGEWOOD TERM via GATES',
#         u'DestinationRef': u'MTA_801117',
#         u'DirectionRef': u'0',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-23',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Saturday-092300_B52_116'},
#         u'JourneyPatternRef': u'MTA_B520040',
#         u'LineRef': u'MTA NYCT_B52',
#         u'Monitored': True,
#         u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-23T16:15:01.391-04:00',
#          u'ExpectedDepartureTime': u'2017-09-23T16:15:01.391-04:00',
#          u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#            u'DistanceFromCall': 6.22,
#            u'PresentableDistance': u'at stop',
#            u'StopsFromCall': 0}},
#          u'StopPointName': u'GATES AV/BROADWAY',
#          u'StopPointRef': u'MTA_307686',
#          u'VisitNumber': 1},
#         u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-23T16:15:00.391-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#              u'DistanceFromCall': 6.22,
#              u'PresentableDistance': u'at stop',
#              u'StopsFromCall': 0}},
#            u'StopPointName': u'GATES AV/BROADWAY',
#            u'StopPointRef': u'MTA_307686'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:16:11.771-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#              u'DistanceFromCall': 250.74,
#              u'PresentableDistance': u'1 stop away',
#              u'StopsFromCall': 1}},
#            u'StopPointName': u'GATES AV/BUSHWICK AV',
#            u'StopPointRef': u'MTA_307687'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:17:04.525-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#              u'DistanceFromCall': 420.13,
#              u'PresentableDistance': u'2 stops away',
#              u'StopsFromCall': 2}},
#            u'StopPointName': u'GATES AV/EVERGREEN AV',
#            u'StopPointRef': u'MTA_307688'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:18:16.229-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#              u'DistanceFromCall': 662.02,
#              u'PresentableDistance': u'3 stops away',
#              u'StopsFromCall': 3}},
#            u'StopPointName': u'GATES AV/CENTRAL AV',
#            u'StopPointRef': u'MTA_307689'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:19:19.829-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#              u'DistanceFromCall': 864.45,
#              u'PresentableDistance': u'0.5 miles away',
#              u'StopsFromCall': 4}},
#            u'StopPointName': u'GATES AV/WILSON AV',
#            u'StopPointRef': u'MTA_307690'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:20:23.829-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#              u'DistanceFromCall': 1070.52,
#              u'PresentableDistance': u'0.7 miles away',
#              u'StopsFromCall': 5}},
#            u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#            u'StopPointRef': u'MTA_307691'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:21:43.521-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#              u'DistanceFromCall': 1369.8,
#              u'PresentableDistance': u'0.9 miles away',
#              u'StopsFromCall': 6}},
#            u'StopPointName': u'PALMETTO ST/IRVING AV',
#            u'StopPointRef': u'MTA_304415'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:22:18.521-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#              u'DistanceFromCall': 1519.71,
#              u'PresentableDistance': u'0.9 miles away',
#              u'StopsFromCall': 7}},
#            u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#            u'StopPointRef': u'MTA_801117'}]},
#         u'OperatorRef': u'MTA NYCT',
#         u'OriginRef': u'MTA_307175',
#         u'ProgressRate': u'normalProgress',
#         u'PublishedLineName': u'B52',
#         u'SituationRef': [],
#         u'VehicleLocation': {u'Latitude': 40.689463, u'Longitude': -73.922296},
#         u'VehicleRef': u'MTA NYCT_6508'},
#        u'RecordedAtTime': u'2017-09-23T16:14:34.000-04:00'},
#       {u'MonitoredVehicleJourney': {u'Bearing': 6.5292053,
#         u'BlockRef': u'MTA NYCT_FP_D7-Saturday_A_FP_52140_B52-115',
#         u'DestinationName': u'RIDGEWOOD TERM via GATES',
#         u'DestinationRef': u'MTA_801117',
#         u'DirectionRef': u'0',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-23',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Saturday-094000_B52_115'},
#         u'JourneyPatternRef': u'MTA_B520040',
#         u'LineRef': u'MTA NYCT_B52',
#         u'Monitored': True,
#         u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-23T16:15:01.391-04:00',
#          u'ExpectedDepartureTime': u'2017-09-23T16:15:01.391-04:00',
#          u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#            u'DistanceFromCall': 14.68,
#            u'PresentableDistance': u'at stop',
#            u'StopsFromCall': 0}},
#          u'StopPointName': u'GATES AV/NOSTRAND AV',
#          u'StopPointRef': u'MTA_307676',
#          u'VisitNumber': 1},
#         u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-23T16:15:00.391-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#              u'DistanceFromCall': 14.68,
#              u'PresentableDistance': u'at stop',
#              u'StopsFromCall': 0}},
#            u'StopPointName': u'GATES AV/NOSTRAND AV',
#            u'StopPointRef': u'MTA_307676'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:16:23.258-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.33,
#              u'DistanceFromCall': 340.06,
#              u'PresentableDistance': u'1 stop away',
#              u'StopsFromCall': 1}},
#            u'StopPointName': u'GATES AV/MARCY AV',
#            u'StopPointRef': u'MTA_307677'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:17:43.258-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4849.89,
#              u'DistanceFromCall': 589.62,
#              u'PresentableDistance': u'2 stops away',
#              u'StopsFromCall': 2}},
#            u'StopPointName': u'GATES AV/TOMPKINS AV',
#            u'StopPointRef': u'MTA_307678'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:18:51.900-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5087.05,
#              u'DistanceFromCall': 826.78,
#              u'PresentableDistance': u'0.5 miles away',
#              u'StopsFromCall': 3}},
#            u'StopPointName': u'GATES AV/THROOP AV',
#            u'StopPointRef': u'MTA_307679'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:20:10.900-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5326.1,
#              u'DistanceFromCall': 1065.83,
#              u'PresentableDistance': u'0.7 miles away',
#              u'StopsFromCall': 4}},
#            u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#            u'StopPointRef': u'MTA_307680'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:21:42.502-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5574.85,
#              u'DistanceFromCall': 1314.58,
#              u'PresentableDistance': u'0.8 miles away',
#              u'StopsFromCall': 5}},
#            u'StopPointName': u'GATES AV/LEWIS AV',
#            u'StopPointRef': u'MTA_307681'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:22:50.502-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#              u'DistanceFromCall': 1566.19,
#              u'PresentableDistance': u'1.0 miles away',
#              u'StopsFromCall': 6}},
#            u'StopPointName': u'GATES AV/STUYVESANT AV',
#            u'StopPointRef': u'MTA_307682'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:24:13.711-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.85,
#              u'DistanceFromCall': 1815.58,
#              u'PresentableDistance': u'1.1 miles away',
#              u'StopsFromCall': 7}},
#            u'StopPointName': u'GATES AV/MALCOLM X BL',
#            u'StopPointRef': u'MTA_307683'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:25:16.141-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#              u'DistanceFromCall': 2061.64,
#              u'PresentableDistance': u'1.3 miles away',
#              u'StopsFromCall': 8}},
#            u'StopPointName': u'GATES AV/PATCHEN AV',
#            u'StopPointRef': u'MTA_307684'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:26:23.116-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#              u'DistanceFromCall': 2295.69,
#              u'PresentableDistance': u'1.4 miles away',
#              u'StopsFromCall': 9}},
#            u'StopPointName': u'GATES AV/RALPH AV',
#            u'StopPointRef': u'MTA_307901'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:27:24.316-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#              u'DistanceFromCall': 2457.53,
#              u'PresentableDistance': u'1.5 miles away',
#              u'StopsFromCall': 10}},
#            u'StopPointName': u'GATES AV/BROADWAY',
#            u'StopPointRef': u'MTA_307686'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:28:59.734-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#              u'DistanceFromCall': 2702.04,
#              u'PresentableDistance': u'1.7 miles away',
#              u'StopsFromCall': 11}},
#            u'StopPointName': u'GATES AV/BUSHWICK AV',
#            u'StopPointRef': u'MTA_307687'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:29:52.488-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#              u'DistanceFromCall': 2871.44,
#              u'PresentableDistance': u'1.8 miles away',
#              u'StopsFromCall': 12}},
#            u'StopPointName': u'GATES AV/EVERGREEN AV',
#            u'StopPointRef': u'MTA_307688'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:31:04.192-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#              u'DistanceFromCall': 3113.32,
#              u'PresentableDistance': u'1.9 miles away',
#              u'StopsFromCall': 13}},
#            u'StopPointName': u'GATES AV/CENTRAL AV',
#            u'StopPointRef': u'MTA_307689'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:32:07.792-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#              u'DistanceFromCall': 3315.75,
#              u'PresentableDistance': u'2.1 miles away',
#              u'StopsFromCall': 14}},
#            u'StopPointName': u'GATES AV/WILSON AV',
#            u'StopPointRef': u'MTA_307690'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:33:11.792-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#              u'DistanceFromCall': 3521.82,
#              u'PresentableDistance': u'2.2 miles away',
#              u'StopsFromCall': 15}},
#            u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#            u'StopPointRef': u'MTA_307691'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:34:31.484-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#              u'DistanceFromCall': 3821.1,
#              u'PresentableDistance': u'2.4 miles away',
#              u'StopsFromCall': 16}},
#            u'StopPointName': u'PALMETTO ST/IRVING AV',
#            u'StopPointRef': u'MTA_304415'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:35:06.484-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#              u'DistanceFromCall': 3971.01,
#              u'PresentableDistance': u'2.5 miles away',
#              u'StopsFromCall': 17}},
#            u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#            u'StopPointRef': u'MTA_801117'}]},
#         u'OperatorRef': u'MTA NYCT',
#         u'OriginRef': u'MTA_307175',
#         u'ProgressRate': u'normalProgress',
#         u'PublishedLineName': u'B52',
#         u'SituationRef': [],
#         u'VehicleLocation': {u'Latitude': 40.686163, u'Longitude': -73.951041},
#         u'VehicleRef': u'MTA NYCT_6490'},
#        u'RecordedAtTime': u'2017-09-23T16:14:54.000-04:00'},
#       {u'MonitoredVehicleJourney': {u'Bearing': 275.56906,
#         u'BlockRef': u'MTA NYCT_FP_D7-Saturday_A_FP_53580_B54-208',
#         u'DestinationName': u'RIDGEWOOD TERM via GATES',
#         u'DestinationRef': u'MTA_801117',
#         u'DirectionRef': u'0',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-23',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Saturday-096500_B54_208'},
#         u'JourneyPatternRef': u'MTA_B520040',
#         u'LineRef': u'MTA NYCT_B52',
#         u'Monitored': True,
#         u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-23T16:15:01.391-04:00',
#          u'ExpectedDepartureTime': u'2017-09-23T16:15:01.391-04:00',
#          u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 598.44,
#            u'DistanceFromCall': 19.94,
#            u'PresentableDistance': u'at stop',
#            u'StopsFromCall': 0}},
#          u'StopPointName': u'ADAMS ST/BKLYN SUPREME CRT',
#          u'StopPointRef': u'MTA_307460',
#          u'VisitNumber': 1},
#         u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-23T16:15:00.391-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 598.44,
#              u'DistanceFromCall': 19.94,
#              u'PresentableDistance': u'at stop',
#              u'StopsFromCall': 0}},
#            u'StopPointName': u'ADAMS ST/BKLYN SUPREME CRT',
#            u'StopPointRef': u'MTA_307460'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:16:58.187-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 797.4,
#              u'DistanceFromCall': 218.91,
#              u'PresentableDistance': u'1 stop away',
#              u'StopsFromCall': 1}},
#            u'StopPointName': u'FULTON ST/SMITH ST',
#            u'StopPointRef': u'MTA_302945'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:18:50.587-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 986.57,
#              u'DistanceFromCall': 408.08,
#              u'PresentableDistance': u'2 stops away',
#              u'StopsFromCall': 2}},
#            u'StopPointName': u'FULTON ST/HOYT ST',
#            u'StopPointRef': u'MTA_307491'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:21:03.791-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1220.03,
#              u'DistanceFromCall': 641.54,
#              u'PresentableDistance': u'3 stops away',
#              u'StopsFromCall': 3}},
#            u'StopPointName': u'FULTON ST/BOND ST',
#            u'StopPointRef': u'MTA_302947'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:22:41.791-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1393.71,
#              u'DistanceFromCall': 815.21,
#              u'PresentableDistance': u'0.5 miles away',
#              u'StopsFromCall': 4}},
#            u'StopPointName': u'FULTON ST/FLATBUSH AV EXT',
#            u'StopPointRef': u'MTA_302948'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:24:59.991-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1683.32,
#              u'DistanceFromCall': 1104.82,
#              u'PresentableDistance': u'0.7 miles away',
#              u'StopsFromCall': 5}},
#            u'StopPointName': u'FULTON ST/ASHLAND PL',
#            u'StopPointRef': u'MTA_303017'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:26:00.553-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1831.55,
#              u'DistanceFromCall': 1253.06,
#              u'PresentableDistance': u'0.8 miles away',
#              u'StopsFromCall': 6}},
#            u'StopPointName': u'FULTON ST/LAFAYETTE AV',
#            u'StopPointRef': u'MTA_302368'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:27:58.147-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2085.33,
#              u'DistanceFromCall': 1506.83,
#              u'PresentableDistance': u'0.9 miles away',
#              u'StopsFromCall': 7}},
#            u'StopPointName': u'FULTON ST/S PORTLAND AV',
#            u'StopPointRef': u'MTA_302369'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:28:50.427-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2214.42,
#              u'DistanceFromCall': 1635.92,
#              u'PresentableDistance': u'1.0 miles away',
#              u'StopsFromCall': 8}},
#            u'StopPointName': u'GREENE AV/FULTON ST',
#            u'StopPointRef': u'MTA_307547'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:30:00.227-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2427.7,
#              u'DistanceFromCall': 1849.2,
#              u'PresentableDistance': u'1.1 miles away',
#              u'StopsFromCall': 9}},
#            u'StopPointName': u'GREENE AV/ADELPHI ST',
#            u'StopPointRef': u'MTA_307548'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:30:53.189-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2599.71,
#              u'DistanceFromCall': 2021.22,
#              u'PresentableDistance': u'1.3 miles away',
#              u'StopsFromCall': 10}},
#            u'StopPointName': u'GREENE AV/VANDERBILT AV',
#            u'StopPointRef': u'MTA_307549'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:32:23.189-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2849.35,
#              u'DistanceFromCall': 2270.85,
#              u'PresentableDistance': u'1.4 miles away',
#              u'StopsFromCall': 11}},
#            u'StopPointName': u'GREENE AV/WASHINGTON AV',
#            u'StopPointRef': u'MTA_307550'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:33:41.254-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3107.79,
#              u'DistanceFromCall': 2529.29,
#              u'PresentableDistance': u'1.6 miles away',
#              u'StopsFromCall': 12}},
#            u'StopPointName': u'GREENE AV/GRAND AV',
#            u'StopPointRef': u'MTA_307551'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:34:45.654-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3346.41,
#              u'DistanceFromCall': 2767.92,
#              u'PresentableDistance': u'1.7 miles away',
#              u'StopsFromCall': 13}},
#            u'StopPointName': u'GREENE AV/CLASSON AV',
#            u'StopPointRef': u'MTA_307552'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:35:45.674-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3579.59,
#              u'DistanceFromCall': 3001.09,
#              u'PresentableDistance': u'1.9 miles away',
#              u'StopsFromCall': 14}},
#            u'StopPointName': u'FRANKLIN AV/GREENE AV',
#            u'StopPointRef': u'MTA_307553'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:36:49.474-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3827.24,
#              u'DistanceFromCall': 3248.74,
#              u'PresentableDistance': u'2.0 miles away',
#              u'StopsFromCall': 15}},
#            u'StopPointName': u'GATES AV/FRANKLIN AV',
#            u'StopPointRef': u'MTA_307674'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:38:33.345-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.77,
#              u'DistanceFromCall': 3432.28,
#              u'PresentableDistance': u'2.1 miles away',
#              u'StopsFromCall': 16}},
#            u'StopPointName': u'GATES AV/BEDFORD AV',
#            u'StopPointRef': u'MTA_307675'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:39:46.394-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#              u'DistanceFromCall': 3696.45,
#              u'PresentableDistance': u'2.3 miles away',
#              u'StopsFromCall': 17}},
#            u'StopPointName': u'GATES AV/NOSTRAND AV',
#            u'StopPointRef': u'MTA_307676'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:41:11.594-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.33,
#              u'DistanceFromCall': 4021.84,
#              u'PresentableDistance': u'2.5 miles away',
#              u'StopsFromCall': 18}},
#            u'StopPointName': u'GATES AV/MARCY AV',
#            u'StopPointRef': u'MTA_307677'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:42:31.594-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4849.89,
#              u'DistanceFromCall': 4271.39,
#              u'PresentableDistance': u'2.7 miles away',
#              u'StopsFromCall': 19}},
#            u'StopPointName': u'GATES AV/TOMPKINS AV',
#            u'StopPointRef': u'MTA_307678'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:43:40.236-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5087.05,
#              u'DistanceFromCall': 4508.55,
#              u'PresentableDistance': u'2.8 miles away',
#              u'StopsFromCall': 20}},
#            u'StopPointName': u'GATES AV/THROOP AV',
#            u'StopPointRef': u'MTA_307679'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:44:59.236-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5326.1,
#              u'DistanceFromCall': 4747.6,
#              u'PresentableDistance': u'3.0 miles away',
#              u'StopsFromCall': 21}},
#            u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#            u'StopPointRef': u'MTA_307680'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:46:30.838-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5574.85,
#              u'DistanceFromCall': 4996.35,
#              u'PresentableDistance': u'3.1 miles away',
#              u'StopsFromCall': 22}},
#            u'StopPointName': u'GATES AV/LEWIS AV',
#            u'StopPointRef': u'MTA_307681'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:47:38.838-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#              u'DistanceFromCall': 5247.96,
#              u'PresentableDistance': u'3.3 miles away',
#              u'StopsFromCall': 23}},
#            u'StopPointName': u'GATES AV/STUYVESANT AV',
#            u'StopPointRef': u'MTA_307682'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:49:02.047-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.85,
#              u'DistanceFromCall': 5497.36,
#              u'PresentableDistance': u'3.4 miles away',
#              u'StopsFromCall': 24}},
#            u'StopPointName': u'GATES AV/MALCOLM X BL',
#            u'StopPointRef': u'MTA_307683'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:50:04.477-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#              u'DistanceFromCall': 5743.41,
#              u'PresentableDistance': u'3.6 miles away',
#              u'StopsFromCall': 25}},
#            u'StopPointName': u'GATES AV/PATCHEN AV',
#            u'StopPointRef': u'MTA_307684'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:51:11.452-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#              u'DistanceFromCall': 5977.46,
#              u'PresentableDistance': u'3.7 miles away',
#              u'StopsFromCall': 26}},
#            u'StopPointName': u'GATES AV/RALPH AV',
#            u'StopPointRef': u'MTA_307901'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:52:12.652-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#              u'DistanceFromCall': 6139.3,
#              u'PresentableDistance': u'3.8 miles away',
#              u'StopsFromCall': 27}},
#            u'StopPointName': u'GATES AV/BROADWAY',
#            u'StopPointRef': u'MTA_307686'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:53:48.070-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#              u'DistanceFromCall': 6383.81,
#              u'PresentableDistance': u'4.0 miles away',
#              u'StopsFromCall': 28}},
#            u'StopPointName': u'GATES AV/BUSHWICK AV',
#            u'StopPointRef': u'MTA_307687'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:54:40.824-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#              u'DistanceFromCall': 6553.21,
#              u'PresentableDistance': u'4.1 miles away',
#              u'StopsFromCall': 29}},
#            u'StopPointName': u'GATES AV/EVERGREEN AV',
#            u'StopPointRef': u'MTA_307688'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:55:52.528-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#              u'DistanceFromCall': 6795.09,
#              u'PresentableDistance': u'4.2 miles away',
#              u'StopsFromCall': 30}},
#            u'StopPointName': u'GATES AV/CENTRAL AV',
#            u'StopPointRef': u'MTA_307689'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:56:56.128-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#              u'DistanceFromCall': 6997.52,
#              u'PresentableDistance': u'4.3 miles away',
#              u'StopsFromCall': 31}},
#            u'StopPointName': u'GATES AV/WILSON AV',
#            u'StopPointRef': u'MTA_307690'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:58:00.128-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#              u'DistanceFromCall': 7203.6,
#              u'PresentableDistance': u'4.5 miles away',
#              u'StopsFromCall': 32}},
#            u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#            u'StopPointRef': u'MTA_307691'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:59:19.820-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#              u'DistanceFromCall': 7502.88,
#              u'PresentableDistance': u'4.7 miles away',
#              u'StopsFromCall': 33}},
#            u'StopPointName': u'PALMETTO ST/IRVING AV',
#            u'StopPointRef': u'MTA_304415'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:59:54.820-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#              u'DistanceFromCall': 7652.78,
#              u'PresentableDistance': u'4.8 miles away',
#              u'StopsFromCall': 34}},
#            u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#            u'StopPointRef': u'MTA_801117'}]},
#         u'OperatorRef': u'MTA NYCT',
#         u'OriginRef': u'MTA_307175',
#         u'ProgressRate': u'normalProgress',
#         u'PublishedLineName': u'B52',
#         u'SituationRef': [],
#         u'VehicleLocation': {u'Latitude': 40.692743, u'Longitude': -73.989092},
#         u'VehicleRef': u'MTA NYCT_6539'},
#        u'RecordedAtTime': u'2017-09-23T16:14:46.000-04:00'},
#       {u'MonitoredVehicleJourney': {u'Bearing': 186.37434,
#         u'BlockRef': u'MTA NYCT_FP_D7-Saturday_A_FP_57060_B52-119',
#         u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#         u'DestinationRef': u'MTA_901463',
#         u'DirectionRef': u'1',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-23',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Saturday-096300_B52_119'},
#         u'JourneyPatternRef': u'MTA_B520048',
#         u'LineRef': u'MTA NYCT_B52',
#         u'Monitored': True,
#         u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-23T16:15:03.420-04:00',
#          u'ExpectedDepartureTime': u'2017-09-23T16:15:03.420-04:00',
#          u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1901.08,
#            u'DistanceFromCall': 52.62,
#            u'PresentableDistance': u'approaching',
#            u'StopsFromCall': 0}},
#          u'StopPointName': u'GATES AV/RALPH AV',
#          u'StopPointRef': u'MTA_304203',
#          u'VisitNumber': 1},
#         u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-23T16:15:03.420-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1901.08,
#              u'DistanceFromCall': 52.62,
#              u'PresentableDistance': u'approaching',
#              u'StopsFromCall': 0}},
#            u'StopPointName': u'GATES AV/RALPH AV',
#            u'StopPointRef': u'MTA_304203'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:16:26.130-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2178.14,
#              u'DistanceFromCall': 329.67,
#              u'PresentableDistance': u'1 stop away',
#              u'StopsFromCall': 1}},
#            u'StopPointName': u'GATES AV/PATCHEN AV',
#            u'StopPointRef': u'MTA_304204'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:18:07.162-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2430.58,
#              u'DistanceFromCall': 582.12,
#              u'PresentableDistance': u'2 stops away',
#              u'StopsFromCall': 2}},
#            u'StopPointName': u'GATES AV/MALCOLM X BL',
#            u'StopPointRef': u'MTA_304205'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:19:38.474-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2679.29,
#              u'DistanceFromCall': 830.83,
#              u'PresentableDistance': u'0.5 miles away',
#              u'StopsFromCall': 3}},
#            u'StopPointName': u'GATES AV/STUYVESANT AV',
#            u'StopPointRef': u'MTA_304206'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:20:23.715-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2883.11,
#              u'DistanceFromCall': 1034.65,
#              u'PresentableDistance': u'0.6 miles away',
#              u'StopsFromCall': 4}},
#            u'StopPointName': u'GATES AV/LEWIS AV',
#            u'StopPointRef': u'MTA_304207'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:22:23.830-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3177.93,
#              u'DistanceFromCall': 1329.46,
#              u'PresentableDistance': u'0.8 miles away',
#              u'StopsFromCall': 5}},
#            u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#            u'StopPointRef': u'MTA_306530'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:23:14.830-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3373.19,
#              u'DistanceFromCall': 1524.73,
#              u'PresentableDistance': u'0.9 miles away',
#              u'StopsFromCall': 6}},
#            u'StopPointName': u'GATES AV/THROOP AV',
#            u'StopPointRef': u'MTA_304209'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:25:08.873-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3659.93,
#              u'DistanceFromCall': 1811.46,
#              u'PresentableDistance': u'1.1 miles away',
#              u'StopsFromCall': 7}},
#            u'StopPointName': u'GATES AV/TOMPKINS AV',
#            u'StopPointRef': u'MTA_304210'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:26:52.473-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 3902.63,
#              u'DistanceFromCall': 2054.17,
#              u'PresentableDistance': u'1.3 miles away',
#              u'StopsFromCall': 8}},
#            u'StopPointName': u'GATES AV/MARCY AV',
#            u'StopPointRef': u'MTA_304211'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:28:14.873-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4182.76,
#              u'DistanceFromCall': 2334.29,
#              u'PresentableDistance': u'1.5 miles away',
#              u'StopsFromCall': 9}},
#            u'StopPointName': u'GATES AV/NOSTRAND AV',
#            u'StopPointRef': u'MTA_304212'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:30:10.093-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#              u'DistanceFromCall': 2648.05,
#              u'PresentableDistance': u'1.6 miles away',
#              u'StopsFromCall': 10}},
#            u'StopPointName': u'GATES AV/BEDFORD AV',
#            u'StopPointRef': u'MTA_304213'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:31:29.494-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#              u'DistanceFromCall': 2827.03,
#              u'PresentableDistance': u'1.8 miles away',
#              u'StopsFromCall': 11}},
#            u'StopPointName': u'GATES AV/FRANKLIN AV',
#            u'StopPointRef': u'MTA_304214'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:32:18.606-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#              u'DistanceFromCall': 3015.61,
#              u'PresentableDistance': u'1.9 miles away',
#              u'StopsFromCall': 12}},
#            u'StopPointName': u'GATES AV/CLASSON AV',
#            u'StopPointRef': u'MTA_307948'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:33:54.806-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#              u'DistanceFromCall': 3308.23,
#              u'PresentableDistance': u'2.1 miles away',
#              u'StopsFromCall': 13}},
#            u'StopPointName': u'GREENE AV/CLASSON AV',
#            u'StopPointRef': u'MTA_307572'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:35:02.006-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#              u'DistanceFromCall': 3550.23,
#              u'PresentableDistance': u'2.2 miles away',
#              u'StopsFromCall': 14}},
#            u'StopPointName': u'GREENE AV/GRAND AV',
#            u'StopPointRef': u'MTA_307573'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:36:14.368-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#              u'DistanceFromCall': 3808.01,
#              u'PresentableDistance': u'2.4 miles away',
#              u'StopsFromCall': 15}},
#            u'StopPointName': u'GREENE AV/WASHINGTON AV',
#            u'StopPointRef': u'MTA_307596'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:37:41.102-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#              u'DistanceFromCall': 4060.44,
#              u'PresentableDistance': u'2.5 miles away',
#              u'StopsFromCall': 16}},
#            u'StopPointName': u'GREENE AV/VANDERBILT AV',
#            u'StopPointRef': u'MTA_307575'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:38:32.521-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#              u'DistanceFromCall': 4226.82,
#              u'PresentableDistance': u'2.6 miles away',
#              u'StopsFromCall': 17}},
#            u'StopPointName': u'GREENE AV/ADELPHI ST',
#            u'StopPointRef': u'MTA_307576'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:39:23.433-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#              u'DistanceFromCall': 4391.02,
#              u'PresentableDistance': u'2.7 miles away',
#              u'StopsFromCall': 18}},
#            u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#            u'StopPointRef': u'MTA_307577'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:41:33.852-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#              u'DistanceFromCall': 4633.93,
#              u'PresentableDistance': u'2.9 miles away',
#              u'StopsFromCall': 19}},
#            u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#            u'StopPointRef': u'MTA_302427'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:42:43.447-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#              u'DistanceFromCall': 4791.08,
#              u'PresentableDistance': u'3.0 miles away',
#              u'StopsFromCall': 20}},
#            u'StopPointName': u'FULTON ST/FT GREENE PL',
#            u'StopPointRef': u'MTA_302428'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:44:45.866-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#              u'DistanceFromCall': 5090.34,
#              u'PresentableDistance': u'3.2 miles away',
#              u'StopsFromCall': 21}},
#            u'StopPointName': u'FULTON ST/HUDSON AV',
#            u'StopPointRef': u'MTA_302430'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:46:49.066-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#              u'DistanceFromCall': 5340.24,
#              u'PresentableDistance': u'3.3 miles away',
#              u'StopsFromCall': 22}},
#            u'StopPointName': u'FULTON ST/BOND ST',
#            u'StopPointRef': u'MTA_302431'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:48:22.229-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#              u'DistanceFromCall': 5545.54,
#              u'PresentableDistance': u'3.4 miles away',
#              u'StopsFromCall': 23}},
#            u'StopPointName': u'FULTON ST/DUFFIELD ST',
#            u'StopPointRef': u'MTA_307492'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:50:02.029-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#              u'DistanceFromCall': 5755.83,
#              u'PresentableDistance': u'3.6 miles away',
#              u'StopsFromCall': 24}},
#            u'StopPointName': u'FULTON ST/JAY ST',
#            u'StopPointRef': u'MTA_302433'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:52:21.429-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#              u'DistanceFromCall': 6081.27,
#              u'PresentableDistance': u'3.8 miles away',
#              u'StopsFromCall': 25}},
#            u'StopPointName': u'JORALEMON ST/COURT ST',
#            u'StopPointRef': u'MTA_302434'},
#           {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#              u'DistanceFromCall': 6211.19,
#              u'PresentableDistance': u'3.9 miles away',
#              u'StopsFromCall': 26}},
#            u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#            u'StopPointRef': u'MTA_306533'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:53:25.229-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#              u'DistanceFromCall': 6249.45,
#              u'PresentableDistance': u'3.9 miles away',
#              u'StopsFromCall': 27}},
#            u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#            u'StopPointRef': u'MTA_901463'}]},
#         u'OperatorRef': u'MTA NYCT',
#         u'OriginRef': u'MTA_504965',
#         u'ProgressRate': u'normalProgress',
#         u'PublishedLineName': u'B52',
#         u'SituationRef': [],
#         u'VehicleLocation': {u'Latitude': 40.689296, u'Longitude': -73.923782},
#         u'VehicleRef': u'MTA NYCT_3975'},
#        u'RecordedAtTime': u'2017-09-23T16:14:37.000-04:00'},
#       {u'MonitoredVehicleJourney': {u'Bearing': 6.634797,
#         u'BlockRef': u'MTA NYCT_FP_D7-Saturday_A_FP_45360_B52-113',
#         u'DestinationName': u'RIDGEWOOD TERM via GATES',
#         u'DestinationRef': u'MTA_801117',
#         u'DirectionRef': u'0',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-23',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Saturday-094800_B52_113'},
#         u'JourneyPatternRef': u'MTA_B520040',
#         u'LineRef': u'MTA NYCT_B52',
#         u'Monitored': True,
#         u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-23T16:15:01.535-04:00',
#          u'ExpectedDepartureTime': u'2017-09-23T16:15:01.535-04:00',
#          u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.77,
#            u'DistanceFromCall': 53.98,
#            u'PresentableDistance': u'approaching',
#            u'StopsFromCall': 0}},
#          u'StopPointName': u'GATES AV/BEDFORD AV',
#          u'StopPointRef': u'MTA_307675',
#          u'VisitNumber': 1},
#         u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-23T16:15:01.535-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.77,
#              u'DistanceFromCall': 53.98,
#              u'PresentableDistance': u'approaching',
#              u'StopsFromCall': 0}},
#            u'StopPointName': u'GATES AV/BEDFORD AV',
#            u'StopPointRef': u'MTA_307675'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:16:14.584-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#              u'DistanceFromCall': 318.15,
#              u'PresentableDistance': u'1 stop away',
#              u'StopsFromCall': 1}},
#            u'StopPointName': u'GATES AV/NOSTRAND AV',
#            u'StopPointRef': u'MTA_307676'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:17:39.784-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.33,
#              u'DistanceFromCall': 643.54,
#              u'PresentableDistance': u'2 stops away',
#              u'StopsFromCall': 2}},
#            u'StopPointName': u'GATES AV/MARCY AV',
#            u'StopPointRef': u'MTA_307677'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:18:59.784-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4849.89,
#              u'DistanceFromCall': 893.09,
#              u'PresentableDistance': u'0.6 miles away',
#              u'StopsFromCall': 3}},
#            u'StopPointName': u'GATES AV/TOMPKINS AV',
#            u'StopPointRef': u'MTA_307678'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:20:08.426-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5087.05,
#              u'DistanceFromCall': 1130.25,
#              u'PresentableDistance': u'0.7 miles away',
#              u'StopsFromCall': 4}},
#            u'StopPointName': u'GATES AV/THROOP AV',
#            u'StopPointRef': u'MTA_307679'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:21:27.426-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5326.1,
#              u'DistanceFromCall': 1369.31,
#              u'PresentableDistance': u'0.9 miles away',
#              u'StopsFromCall': 5}},
#            u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#            u'StopPointRef': u'MTA_307680'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:22:59.028-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5574.85,
#              u'DistanceFromCall': 1618.05,
#              u'PresentableDistance': u'1.0 miles away',
#              u'StopsFromCall': 6}},
#            u'StopPointName': u'GATES AV/LEWIS AV',
#            u'StopPointRef': u'MTA_307681'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:24:07.028-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#              u'DistanceFromCall': 1869.67,
#              u'PresentableDistance': u'1.2 miles away',
#              u'StopsFromCall': 7}},
#            u'StopPointName': u'GATES AV/STUYVESANT AV',
#            u'StopPointRef': u'MTA_307682'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:25:30.237-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.85,
#              u'DistanceFromCall': 2119.06,
#              u'PresentableDistance': u'1.3 miles away',
#              u'StopsFromCall': 8}},
#            u'StopPointName': u'GATES AV/MALCOLM X BL',
#            u'StopPointRef': u'MTA_307683'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:26:32.667-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#              u'DistanceFromCall': 2365.11,
#              u'PresentableDistance': u'1.5 miles away',
#              u'StopsFromCall': 9}},
#            u'StopPointName': u'GATES AV/PATCHEN AV',
#            u'StopPointRef': u'MTA_307684'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:27:39.642-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#              u'DistanceFromCall': 2599.17,
#              u'PresentableDistance': u'1.6 miles away',
#              u'StopsFromCall': 10}},
#            u'StopPointName': u'GATES AV/RALPH AV',
#            u'StopPointRef': u'MTA_307901'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:28:40.842-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#              u'DistanceFromCall': 2761.0,
#              u'PresentableDistance': u'1.7 miles away',
#              u'StopsFromCall': 11}},
#            u'StopPointName': u'GATES AV/BROADWAY',
#            u'StopPointRef': u'MTA_307686'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:30:16.260-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#              u'DistanceFromCall': 3005.51,
#              u'PresentableDistance': u'1.9 miles away',
#              u'StopsFromCall': 12}},
#            u'StopPointName': u'GATES AV/BUSHWICK AV',
#            u'StopPointRef': u'MTA_307687'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:31:09.014-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#              u'DistanceFromCall': 3174.91,
#              u'PresentableDistance': u'2.0 miles away',
#              u'StopsFromCall': 13}},
#            u'StopPointName': u'GATES AV/EVERGREEN AV',
#            u'StopPointRef': u'MTA_307688'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:32:20.718-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
# ...
#            u'StopPointName': u'GATES AV/FRANKLIN AV',
#            u'StopPointRef': u'MTA_307674'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:40:56.957-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4010.77,
#              u'DistanceFromCall': 3977.46,
#              u'PresentableDistance': u'2.5 miles away',
#              u'StopsFromCall': 17}},
#            u'StopPointName': u'GATES AV/BEDFORD AV',
#            u'StopPointRef': u'MTA_307675'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:42:08.606-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4274.94,
#              u'DistanceFromCall': 4241.62,
#              u'PresentableDistance': u'2.6 miles away',
#              u'StopsFromCall': 18}},
#            u'StopPointName': u'GATES AV/NOSTRAND AV',
#            u'StopPointRef': u'MTA_307676'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:43:33.806-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4600.33,
#              u'DistanceFromCall': 4567.01,
#              u'PresentableDistance': u'2.8 miles away',
#              u'StopsFromCall': 19}},
#            u'StopPointName': u'GATES AV/MARCY AV',
#            u'StopPointRef': u'MTA_307677'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:44:53.806-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4849.89,
#              u'DistanceFromCall': 4816.57,
#              u'PresentableDistance': u'3.0 miles away',
#              u'StopsFromCall': 20}},
#            u'StopPointName': u'GATES AV/TOMPKINS AV',
#            u'StopPointRef': u'MTA_307678'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:46:02.448-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5087.05,
#              u'DistanceFromCall': 5053.73,
#              u'PresentableDistance': u'3.1 miles away',
#              u'StopsFromCall': 21}},
#            u'StopPointName': u'GATES AV/THROOP AV',
#            u'StopPointRef': u'MTA_307679'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:47:21.448-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5326.1,
#              u'DistanceFromCall': 5292.78,
#              u'PresentableDistance': u'3.3 miles away',
#              u'StopsFromCall': 22}},
#            u'StopPointName': u'GATES AV/MARCUS GARVEY BL',
#            u'StopPointRef': u'MTA_307680'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:48:53.050-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5574.85,
#              u'DistanceFromCall': 5541.53,
#              u'PresentableDistance': u'3.4 miles away',
#              u'StopsFromCall': 23}},
#            u'StopPointName': u'GATES AV/LEWIS AV',
#            u'StopPointRef': u'MTA_307681'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:50:01.050-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#              u'DistanceFromCall': 5793.14,
#              u'PresentableDistance': u'3.6 miles away',
#              u'StopsFromCall': 24}},
#            u'StopPointName': u'GATES AV/STUYVESANT AV',
#            u'StopPointRef': u'MTA_307682'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:51:24.259-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.85,
#              u'DistanceFromCall': 6042.53,
#              u'PresentableDistance': u'3.8 miles away',
#              u'StopsFromCall': 25}},
#            u'StopPointName': u'GATES AV/MALCOLM X BL',
#            u'StopPointRef': u'MTA_307683'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:52:26.689-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6321.91,
#              u'DistanceFromCall': 6288.59,
#              u'PresentableDistance': u'3.9 miles away',
#              u'StopsFromCall': 26}},
#            u'StopPointName': u'GATES AV/PATCHEN AV',
#            u'StopPointRef': u'MTA_307684'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:53:33.664-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6555.96,
#              u'DistanceFromCall': 6522.64,
#              u'PresentableDistance': u'4.1 miles away',
#              u'StopsFromCall': 27}},
#            u'StopPointName': u'GATES AV/RALPH AV',
#            u'StopPointRef': u'MTA_307901'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:54:34.864-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6717.8,
#              u'DistanceFromCall': 6684.48,
#              u'PresentableDistance': u'4.2 miles away',
#              u'StopsFromCall': 28}},
#            u'StopPointName': u'GATES AV/BROADWAY',
#            u'StopPointRef': u'MTA_307686'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:56:10.282-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6962.31,
#              u'DistanceFromCall': 6928.99,
#              u'PresentableDistance': u'4.3 miles away',
#              u'StopsFromCall': 29}},
#            u'StopPointName': u'GATES AV/BUSHWICK AV',
#            u'StopPointRef': u'MTA_307687'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:57:03.036-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7131.71,
#              u'DistanceFromCall': 7098.39,
#              u'PresentableDistance': u'4.4 miles away',
#              u'StopsFromCall': 30}},
#            u'StopPointName': u'GATES AV/EVERGREEN AV',
#            u'StopPointRef': u'MTA_307688'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:58:14.740-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7373.59,
#              u'DistanceFromCall': 7340.27,
#              u'PresentableDistance': u'4.6 miles away',
#              u'StopsFromCall': 31}},
#            u'StopPointName': u'GATES AV/CENTRAL AV',
#            u'StopPointRef': u'MTA_307689'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:59:18.340-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7576.02,
#              u'DistanceFromCall': 7542.7,
#              u'PresentableDistance': u'4.7 miles away',
#              u'StopsFromCall': 32}},
#            u'StopPointName': u'GATES AV/WILSON AV',
#            u'StopPointRef': u'MTA_307690'},
#           {u'ExpectedArrivalTime': u'2017-09-23T17:00:22.340-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7782.09,
#              u'DistanceFromCall': 7748.77,
#              u'PresentableDistance': u'4.8 miles away',
#              u'StopsFromCall': 33}},
#            u'StopPointName': u'GATES AV/KNICKERBOCKER AV',
#            u'StopPointRef': u'MTA_307691'},
#           {u'ExpectedArrivalTime': u'2017-09-23T17:01:42.032-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8081.37,
#              u'DistanceFromCall': 8048.05,
#              u'PresentableDistance': u'5.0 miles away',
#              u'StopsFromCall': 34}},
#            u'StopPointName': u'PALMETTO ST/IRVING AV',
#            u'StopPointRef': u'MTA_304415'},
#           {u'ExpectedArrivalTime': u'2017-09-23T17:02:17.032-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8231.28,
#              u'DistanceFromCall': 8197.96,
#              u'PresentableDistance': u'5.1 miles away',
#              u'StopsFromCall': 35}},
#            u'StopPointName': u'PALMETTO ST/WYCKOFF AV',
#            u'StopPointRef': u'MTA_801117'}]},
#         u'OperatorRef': u'MTA NYCT',
#         u'OriginAimedDepartureTime': u'2017-09-23T16:14:00.000-04:00',
#         u'OriginRef': u'MTA_307175',
#         u'ProgressRate': u'noProgress',
#         u'ProgressStatus': u'layover',
#         u'PublishedLineName': u'B52',
#         u'SituationRef': [],
#         u'VehicleLocation': {u'Latitude': 40.696187, u'Longitude': -73.990982},
#         u'VehicleRef': u'MTA NYCT_7285'},
#        u'RecordedAtTime': u'2017-09-23T16:14:39.000-04:00'},
#       {u'MonitoredVehicleJourney': {u'Bearing': 186.53427,
#         u'BlockRef': u'MTA NYCT_FP_D7-Saturday_A_FP_55560_B52-125',
#         u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#         u'DestinationRef': u'MTA_901463',
#         u'DirectionRef': u'1',
#         u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-23',
#          u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Saturday-093800_B52_125'},
#         u'JourneyPatternRef': u'MTA_B520048',
#         u'LineRef': u'MTA NYCT_B52',
#         u'Monitored': True,
#         u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-23T16:15:48.653-04:00',
#          u'ExpectedDepartureTime': u'2017-09-23T16:15:48.653-04:00',
#          u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#            u'DistanceFromCall': 192.4,
#            u'PresentableDistance': u'< 1 stop away',
#            u'StopsFromCall': 0}},
#          u'StopPointName': u'GATES AV/BEDFORD AV',
#          u'StopPointRef': u'MTA_304213',
#          u'VisitNumber': 1},
#         u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-23T16:15:48.653-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4496.51,
#              u'DistanceFromCall': 192.4,
#              u'PresentableDistance': u'< 1 stop away',
#              u'StopsFromCall': 0}},
#            u'StopPointName': u'GATES AV/BEDFORD AV',
#            u'StopPointRef': u'MTA_304213'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:17:08.054-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4675.5,
#              u'DistanceFromCall': 371.38,
#              u'PresentableDistance': u'1 stop away',
#              u'StopsFromCall': 1}},
#            u'StopPointName': u'GATES AV/FRANKLIN AV',
#            u'StopPointRef': u'MTA_304214'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:17:57.166-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 4864.08,
#              u'DistanceFromCall': 559.96,
#              u'PresentableDistance': u'2 stops away',
#              u'StopsFromCall': 2}},
#            u'StopPointName': u'GATES AV/CLASSON AV',
#            u'StopPointRef': u'MTA_307948'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:19:33.366-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5156.7,
#              u'DistanceFromCall': 852.58,
#              u'PresentableDistance': u'0.5 miles away',
#              u'StopsFromCall': 3}},
#            u'StopPointName': u'GREENE AV/CLASSON AV',
#            u'StopPointRef': u'MTA_307572'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:20:40.566-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5398.69,
#              u'DistanceFromCall': 1094.58,
#              u'PresentableDistance': u'0.7 miles away',
#              u'StopsFromCall': 4}},
#            u'StopPointName': u'GREENE AV/GRAND AV',
#            u'StopPointRef': u'MTA_307573'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:21:52.928-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5656.47,
#              u'DistanceFromCall': 1352.36,
#              u'PresentableDistance': u'0.8 miles away',
#              u'StopsFromCall': 5}},
#            u'StopPointName': u'GREENE AV/WASHINGTON AV',
#            u'StopPointRef': u'MTA_307596'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:23:19.662-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#              u'DistanceFromCall': 1604.79,
#              u'PresentableDistance': u'1.0 miles away',
#              u'StopsFromCall': 6}},
#            u'StopPointName': u'GREENE AV/VANDERBILT AV',
#            u'StopPointRef': u'MTA_307575'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:24:11.081-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6075.28,
#              u'DistanceFromCall': 1771.17,
#              u'PresentableDistance': u'1.1 miles away',
#              u'StopsFromCall': 7}},
#            u'StopPointName': u'GREENE AV/ADELPHI ST',
#            u'StopPointRef': u'MTA_307576'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:25:01.993-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6239.48,
#              u'DistanceFromCall': 1935.37,
#              u'PresentableDistance': u'1.2 miles away',
#              u'StopsFromCall': 8}},
#            u'StopPointName': u'GREENE AV/CUMBERLAND ST',
#            u'StopPointRef': u'MTA_307577'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:27:12.412-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6482.4,
#              u'DistanceFromCall': 2178.28,
#              u'PresentableDistance': u'1.4 miles away',
#              u'StopsFromCall': 9}},
#            u'StopPointName': u'FULTON ST/S ELLIOTT PL',
#            u'StopPointRef': u'MTA_302427'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:28:22.007-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6639.55,
#              u'DistanceFromCall': 2335.43,
#              u'PresentableDistance': u'1.5 miles away',
#              u'StopsFromCall': 10}},
#            u'StopPointName': u'FULTON ST/FT GREENE PL',
#            u'StopPointRef': u'MTA_302428'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:30:24.426-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6938.8,
#              u'DistanceFromCall': 2634.69,
#              u'PresentableDistance': u'1.6 miles away',
#              u'StopsFromCall': 11}},
#            u'StopPointName': u'FULTON ST/HUDSON AV',
#            u'StopPointRef': u'MTA_302430'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:32:27.626-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7188.7,
#              u'DistanceFromCall': 2884.59,
#              u'PresentableDistance': u'1.8 miles away',
#              u'StopsFromCall': 12}},
#            u'StopPointName': u'FULTON ST/BOND ST',
#            u'StopPointRef': u'MTA_302431'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:34:00.789-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7394.01,
#              u'DistanceFromCall': 3089.89,
#              u'PresentableDistance': u'1.9 miles away',
#              u'StopsFromCall': 13}},
#            u'StopPointName': u'FULTON ST/DUFFIELD ST',
#            u'StopPointRef': u'MTA_307492'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:35:40.589-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7604.3,
#              u'DistanceFromCall': 3300.18,
#              u'PresentableDistance': u'2.1 miles away',
#              u'StopsFromCall': 14}},
#            u'StopPointName': u'FULTON ST/JAY ST',
#            u'StopPointRef': u'MTA_302433'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:37:59.989-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 7929.74,
#              u'DistanceFromCall': 3625.62,
#              u'PresentableDistance': u'2.3 miles away',
#              u'StopsFromCall': 15}},
#            u'StopPointName': u'JORALEMON ST/COURT ST',
#            u'StopPointRef': u'MTA_302434'},
#           {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8059.65,
#              u'DistanceFromCall': 3755.54,
#              u'PresentableDistance': u'2.3 miles away',
#              u'StopsFromCall': 16}},
#            u'StopPointName': u'CADMAN PLZ W/MONTAGUE ST',
#            u'StopPointRef': u'MTA_306533'},
#           {u'ExpectedArrivalTime': u'2017-09-23T16:39:03.789-04:00',
#            u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91,
#              u'DistanceFromCall': 3793.8,
#              u'PresentableDistance': u'2.4 miles away',
#              u'StopsFromCall': 17}},
#            u'StopPointName': u'CADMAN PZ W/TILLARY ST',
#            u'StopPointRef': u'MTA_901463'}]},
#         u'OperatorRef': u'MTA NYCT',
#         u'OriginRef': u'MTA_504965',
#         u'ProgressRate': u'normalProgress',
#         u'PublishedLineName': u'B52',
#         u'SituationRef': [],
#         u'VehicleLocation': {u'Latitude': 40.685987, u'Longitude': -73.952577},
#         u'VehicleRef': u'MTA NYCT_7266'},
#        u'RecordedAtTime': u'2017-09-23T16:14:38.000-04:00'}]}]}}}

# %%
from __future__ import print_function
# the next import allows me to read line input arguments
import sys


# this line checks how many arguments are passed to python
# the arguments are stored in sys.argv which is a list
# the first argument is the name of the code
# so sys.argv is a list with at least one element
# with your name in input it will be a list of 2
# if you add more than one word as argument it will give you an error as well
if not len(sys.argv) == 2:
    print ("Invalid number of arguments. Run as: python  aSimplePythonScript.py YourNameHere")
    sys.exit()

# this line prints Hallo and then your name
# which you provide as argument
print ("Hello " + sys.argv[1] + "!")
# Out:
# Invalid number of arguments. Run as: python  aSimplePythonScript.py YourNameHere
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# To exit: use 'exit', 'quit', or Ctrl-D.
