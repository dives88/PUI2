# %%
#from numpy import *  -- don't want to import NUMPY like this b/c you want to preserve the namespace as the lines below do

import numpy as np
import matplotlib as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rand_numbers = np.random.normal(loc=10, scale=2, size=1000)

rand_numbers_2 = np.random.normal(loc=np.random.normal(5,1), scale=5, size=1000)

# %%
plt.hist(rand_numbers);
plt.hist(rand_numbers_2, alpha =.5);

# %%
rando_binomial = np.random.binomial(n = 10, p = 0.5, size=1000)

# %%
plt.hist(rando_binomial);

# %%
np.mean(rando_binomial)
# Out:
# 5.0250000000000004

# %%
rando_poisson_1 = np.random.poisson(lam = 1, size = 1000)
rando_poisson_2 = np.random.poisson(lam = 1000, size = 1000)

# %%
plt.hist(rando_poisson_1)
# Out:
# (array([ 376.,    0.,  382.,    0.,  176.,    0.,   47.,    0.,   16.,    3.]),
#  array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(rando_poisson_2)
# Out:
# (array([   4.,   20.,   89.,  169.,  249.,  230.,  139.,   74.,   20.,    6.]),
#  array([  899. ,   919.5,   940. ,   960.5,   981. ,  1001.5,  1022. ,
#          1042.5,  1063. ,  1083.5,  1104. ]),
#  <a list of 10 Patch objects>)
